# %% [markdown]
# # Entitled cell with image inserted
#
# - Linked image
#
# ![alt text](./test.png "Title")
#
# - Embedded image
#
# ![test.png](attachment:test.png)

# %% [markdown]
# Untitled cell with image inserted
#
# - Linked image
#
# ![alt text](./test.png "Title")
#
# - Embedded image
#
# ![test.png](attachment:test.png)

# %% [markdown]
# # Header [with](link) link
#
# ### Header with &#8593; anchor-like &#9650; symbols &#9757;
#
# - Some text with &#8593; anchor-like &#9650; symbols &#9757;
#
# ### Header [with](link) link and [with](link) link [lv2](link)
#
#
# - Some text
#
# ### [Whole header as link](link)

# %% [markdown]
# # Русский заголовок ур1
#
# ## Још један наслов lv2
#
# ### 另一个标题 lv3
#
# #### Header lv4
#
# Some text
#
#     #### Code block with 4 spaces
#
# Some text
#
#         #### Code block with 8 spaces
#
# Some text
#
# 		#### Code block with 2 tabs
#
# Some text
#
# ```
# # TripleBacktickCodeBlock
# ```
#
# ###### Header lv6 is the last level due to markdown spec
#
# ###### Header lv6 is the last level due to markdown spec
#
# ##### Header lv5
# ##### Header lv5
#
# - not a headers
#
# ####### Not a header due to markdown spec
#
# #1#
#
# ##2
#
# - empty headers (we should skip them but not remove)
#
# #
#
# ##
#
# ###
#
# ####

# %%
import numpy as np
# comment: this is text output cell
arr = np.random.randint(1, 10, size=(2, 5))

arr
# Out:
# array([[6, 2, 2, 7, 1],
#        [6, 8, 7, 9, 2]])

# %% [markdown]
# ### 2020-02-23 Header lv3
#
# Some latex markdown
#
# $$ A = \sum_{i=1}^{n}{a_i} $$
#
# Some inline formula $B \in [0, +\infin)$

# %%
# some latex stuff
from sympy import Symbol

x = Symbol("x")
(x ** 2 + 2 * x + 1) / (x ** 2 - 1)
# Out:
# (x**2 + 2*x + 1)/(x**2 - 1)

# %%
from PIL import Image

print("Some text")
# this is txt & img cell
Image.open("./test.png")
# Out:
# Some text
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=498x310>

# %%
# this is stream cell
# !ls /
# Out:
# afs  boot  etc	 lib	lost+found  mnt		    opt   root	sbin  sys  usr
# bin  dev   home  lib64	media	    Module.symvers  proc  run	srv   tmp  var

# %%
# %%timeit

from functools import lru_cache

@lru_cache(maxsize=None)
def fib(n):
    assert n >= 0
    return n if n <= 1 else fib(n - 1) + fib(n - 2)

fib(100)
# Out:
# 25 μs ± 488 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# #### Long header 123 with 12.3 numbers 5.15.53. like in this Toc numbering lv4
#
# Numbers in title should not be modified/removed
#
# # Header lv1
#
# ## Features lv2

# %% [markdown]
# ### Header lv3
#
# Some other text

# %%
import matplotlib.pyplot as plt


x = np.arange(0, 4*np.pi, 0.1)   # inline comment: start, stop, step
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %% [raw]
# <p># text/html mime type cell</p>
# <p>raw cell</p>

# %% [raw]
# raw cell w/unknown mime type

# %% [markdown]
# ## Features lv2
# ### Usage lv3
# ## Configuration lv2
#
# last cell should process correctly
