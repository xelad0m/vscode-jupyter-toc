# %% [markdown]
# **Содержание**<a id='toc0_'></a>
# - [Header with link ](#toc1_)
# - [Русский заголовок ур1](#toc2_)
#   - [Још један наслов lv2](#toc2_1_)
# - [Header lv1](#toc3_)
#   - [Features lv2](#toc3_1_)
#   - [Features lv2](#toc3_2_)
#   - [Configuration lv2](#toc3_3_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=2
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# # <a id='toc1_'></a>Header [with](link) link  [&#8593;](#toc0_)
#
# ### Header with &#8593; anchor-like &#9650; symbols &#9757;
#
# - Some text with &#8593; anchor-like &#9650; symbols &#9757;
#
# ### Header [with](link) link and [with](link) link [lv2](link)
#
#
# - Some text
#
# ### [Whole header as link](link)

# %% [markdown]
# # <a id='toc2_'></a>[Русский заголовок ур1](#toc0_)
#
# ## <a id='toc2_1_'></a>[Још један наслов lv2](#toc0_)
#
# ### 另一个标题 lv3
#
# #### Header lv4
#
# Some text
#
#     #### Code block with 4 spaces
#
# Some text
#
#         #### Code block with 8 spaces
#
# Some text
#
# 		#### Code block with 2 tabs
#
# Some text
#
# ```
# # TripleBacktickCodeBlock
# ```
#
# ###### Header lv6 is the last level due to markdown spec
#
# ###### Header lv6 is the last level due to markdown spec
#
# ##### Header lv5
# ##### Header lv5
#
# - not a headers
#
# ####### Not a header due to markdown spec
#
# #1#
#
# ##2
#
# - empty headers (we should skip them but not remove)
#
# #
#
# ##
#
# ###
#
# ####

# %%
import numpy as np
# comment: this is text output cell
arr = np.random.randint(1, 10, size=(2, 5))

arr
# Out:
# array([[6, 9, 4, 3, 6],
#        [1, 7, 1, 7, 5]])

# %% [markdown]
# ### 2020-02-23 Header lv3
#
# Some latex markdown
#
# $$ A = \sum_{i=1}^{n}{a_i} $$
#
# Some inline formula $B \in [0, +\infin)$

# %%
# some latex stuff
from sympy import Symbol

x = Symbol("x")
(x ** 2 + 2 * x + 1) / (x ** 2 - 1)
# Out:
# (x**2 + 2*x + 1)/(x**2 - 1)

# %%
from PIL import Image

print("Some text")
# this is txt & img cell
Image.open("./test.png")
# Out:
# Some text
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=498x310>

# %%
# this is stream cell
# !ls /
# Out:
# bin   dev  home  lib64	 lost+found  mnt  proc	run   srv  tmp	var
# boot  etc  lib	 libx32  media	     opt  root	sbin  sys  usr

# %%
# %%timeit

from functools import lru_cache

@lru_cache(maxsize=None)
def fib(n):
    assert n >= 0
    return n if n <= 1 else fib(n - 1) + fib(n - 2)

fib(100)
# Out:
# 40 µs ± 614 ns per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# #### Long header 123 with 12.3 numbers 5.15.53. like in this Toc numbering lv4
#
# Numbers in title should not be modified/removed
#
# # <a id='toc3_'></a>[Header lv1](#toc0_)
#
# ## <a id='toc3_1_'></a>[Features lv2](#toc0_)

# %% [markdown]
# ### Header lv3
#
# Some other text

# %%
import matplotlib.pyplot as plt


x = np.arange(0, 4*np.pi, 0.1)   # inline comment: start, stop, step
y = np.sin(x)

plt.plot(x, y)
plt.show()

# %% [raw]
# <p># text/html mime type cell</p>
# <p>raw cell</p>

# %% [raw]
# raw cell w/unknown mime type

# %% [markdown]
# ## <a id='toc3_2_'></a>[Features lv2](#toc0_)
# ### Usage lv3
# ## <a id='toc3_3_'></a>[Configuration lv2](#toc0_)
#
# last cell should process correctly
